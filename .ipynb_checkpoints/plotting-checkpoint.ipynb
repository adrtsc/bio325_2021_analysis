# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
sns.set_theme(style="darkgrid", palette="tab20")
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
feature_path =  Path(r'Z:\20211014_bio325_test\features')
feature_files = feature_path.glob('*cells_feature_values.csv')
feature_files = [str(fyle) for fyle in feature_files]
fv = []

for site, fyle in enumerate(sorted(feature_files)):
    site_fv = pd.read_csv(fyle)
    site_fv['site'] = site
    site_fv['unique_track_id'] = site_fv['track_id'] + site * 1000
    fv.append(site_fv)
    
    
fv = pd.concat(fv)

# %%
fv.shape
# Out:
# (1823, 245)

# %%
fv.head()
# Out:
#    unique_object_id  timepoint  label    area  bbox-0  bbox-1  bbox-2  bbox-3  \
# 0                 0          0      1  193163       0       0     737     563
# 1                 1          0      2  110729       0     375     536     697
# 2                 2          0      3   22289       0    1138     134    1352
# 3                 3          0      4  229916      14     523     964    1165
# 4                 4          0      5  166034      94     951     817    1326
#
#    bbox_area  centroid-0  ...  orientation_cytoplasm  perimeter_cytoplasm  \
# 0     414931  328.429953  ...               0.548530          3952.450793
# 1     172592  199.811495  ...               0.021235          2289.740115
# 2      28676   55.954372  ...               1.462209           686.727922
# 3     609900  469.128547  ...              -0.562413          4125.107648
# 4     271125  480.333679  ...              -0.234420          3342.509668
#
#    solidity_cytoplasm  max_intensity_sdcGFP_cytoplasm  \
# 0            0.536383                           581.0
# 1            0.495588                           205.0
# 2            0.925469                            95.0
# 3            0.660710                           123.0
# 4            0.566149                           184.0
#
#    mean_intensity_sdcGFP_cytoplasm  min_intensity_sdcGFP_cytoplasm  \
# 0                        11.499358                             0.0
# 1                         4.961404                             0.0
# 2                         5.749069                             0.0
# 3                         5.378520                             0.0
# 4                         7.232483                             0.0
#
#    blob_count_sdcGFP_cytoplasm  site  unique_track_id  count_cytoplasm
# 0                         28.0     0                2              NaN
# 1                          0.0     0                3              NaN
# 2                          1.0     0               26              NaN
# 3                          5.0     0                4              NaN
# 4                         13.0     0                5              NaN
#
# [5 rows x 245 columns]

# %% [markdown]
# # Data clean-up

# %%
# remove tracks that contain cells touching the border
fv = fv.groupby('unique_track_id').filter(lambda x: x['is_border'] == 0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22896/1383290154.py in <module>
#       1 # remove tracks that contain cells touching the border
#       2
# ----> 3 fv.is_border()
#
# ~\miniconda3\envs\bio325_2021\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'is_border'

# %%
sns.scatterplot(data=fv, x='area', y='area_nuclei')
# Out:
# <AxesSubplot:xlabel='area', ylabel='area_nuclei'>

# %%
sns.lineplot(data=fv.set_index('unique_object_id'), x='timepoint', y='area_nuclei', hue='site', palette='tab10')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='area_nuclei'>

# %% [markdown]
# # Volume and density estimation

# %%
# volume = area_pixel * pixel_size_um * imaging_depth_um 
fv['volume_cytoplasm'] = fv['area_cytoplasm'] * 0.108 * 1
fv['blob_sdcGFP_cytoplasm_density'] = fv['blob_count_sdcGFP_cytoplasm']/fv['volume_cytoplasm']

# %%
# filter the cells that have been transfected in the first timepoint
positive_tracks = fv['unique_track_id'].loc[(fv['timepoint'] == 0) & (fv['max_intensity_sdcGFP'] > 100)]                                        
fv_transfected = fv.loc[fv['unique_track_id'].isin(positive_tracks)]

# %%
sns.scatterplot(data=fv_transfected, x='volume_cytoplasm', y='blob_sdcGFP_cytoplasm_density', hue='site', palette='tab20')
# Out:
# <AxesSubplot:xlabel='volume_cytoplasm', ylabel='blob_sdcGFP_cytoplasm_density'>

# %%
sns.lineplot(data=fv_transfected.loc[fv_transfected['site']==1], x='timepoint', y='blob_sdcGFP_cytoplasm_density', hue='unique_track_id', palette='tab10')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='blob_sdcGFP_cytoplasm_density'>

# %%
def generate_heatmap_data(feature):

heatmap_data = fv_transfected[['unique_track_id', 'timepoint', 'blob_sdcGFP_cytoplasm_density']]
heatmap_data = heatmap_data.drop_duplicates(subset=['unique_track_id', 'timepoint'], keep='first')

# remove tracks that do not span the whole movie
heatmap_data = heatmap_data.groupby('unique_track_id').filter(lambda x: len(x) == 11)
heatmap_data = heatmap_data.pivot('unique_track_id', 'timepoint', 'blob_sdcGFP_cytoplasm_density')

ax=sns.heatmap(heatmap_data, cmap='gist_heat')
